# %%
session_vis_path = '/home/gina101/new_data/Eleusis 2.0/Environment/Visualizations'

# %%
session_og_path = '/home/gina101/Eleusis 2.0/Eleusis 2.0'

# %%
import os

# %%
import yaml

# %%
import fnmatch

# %%
import pandas as pd

# %%
thematic_name = 'Environment'
session_id = 1
city_name = 'Eleusis 2.0'

# %%
import re

# %% [markdown]
# # Generating Fixtures for Sessions and Tasks

# %%
section_folders = os.listdir(session_vis_path)

# %%
model_name = 'biosignalsindex.Section'

# %%
sections = []
for folder in section_folders:
  section = {
      'model': model_name,
      'fields':{
        'name': folder,
        'session': [city_name, thematic_name, session_id],
      }
  }
  sections.append(section)

# %%
sections
# Out:
# [{'model': 'biosignalsindex.Task',
#   'fields': {'name': 'Main', 'session': ['Eleusis 2.0', 'Environment', 1]}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'name': 'Introduction',
#    'session': ['Eleusis 2.0', 'Environment', 1]}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'name': 'Conclusion',
#    'session': ['Eleusis 2.0', 'Environment', 1]}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Eleusis 2.0/Environment/Session1/sections.yaml', 'w') as f:
  yaml.safe_dump(sections, f)

# %%
def findTaskNo(name):
  return name.split("Task")[1][0]
  # return name.split('-')[2].split('.xlsx')[0]

# %%
timeFiles_path = os.path.join(session_og_path, 'Tasks')
timeFiles = os.listdir(timeFiles_path)
tasks = []
model_name = 'biosignalsindex.Task'
for folder in section_folders:
  section_path = os.path.join(session_vis_path, folder)
  task_folders = os.listdir(section_path)
  for t_folder in task_folders:
    taskNo = findTaskNo(t_folder)
    timeFile = fnmatch.filter(timeFiles, 'timeTask{}*-{}*'.format(taskNo, folder))[0]
    df = pd.read_excel(os.path.join(timeFiles_path, timeFile), header=None)
    starting_time = df.iloc[0, 0]
    ending_time = df.iloc[-1, 0]
    task = {
        'model': model_name,
        'fields': {
          'session': [city_name, thematic_name, session_id],
          'section': [city_name, thematic_name, session_id, folder],
          'task_no_in_section': taskNo,
          'starting_time': str(round(starting_time, 2)),
          'ending_time': str(round(ending_time, 2))
        }
    }
    tasks.append(task)

# %%
tasks
# Out:
# [{'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Eleusis 2.0', 'Environment', 1],
#    'section': ['Eleusis 2.0', 'Environment', 1, 'Main'],
#    'task_no_in_section': '2',
#    'starting_time': '43.08',
#    'ending_time': '59.98'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Eleusis 2.0', 'Environment', 1],
#    'section': ['Eleusis 2.0', 'Environment', 1, 'Main'],
#    'task_no_in_section': '1',
#    'starting_time': '31.98',
#    'ending_time': '43.08'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Eleusis 2.0', 'Environment', 1],
#    'section': ['Eleusis 2.0', 'Environment', 1, 'Main'],
#    'task_no_in_section': '5',
#    'starting_time': '82.8',
#    'ending_time': '84.38'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Eleusis 2.0', 'Environment', 1],
#    'section': ['Eleusis 2.0', 'Environment', 1, 'Main'],
#    'task_no_in_section': '3',
#    'starting_time': '59.98',
#    'ending_time': '71.67'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Eleusis 2.0', 'Environment', 1],
#    'section': ['Eleusis 2.0', 'Environment', 1, 'Main'],
#    'task_no_in_section': '4',
#    'starting_time': '71.67',
#    'ending_time': '82.8'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Eleusis 2.0', 'Environment', 1],
#    'section': ['Eleusis 2.0', 'Environment', 1, 'Introduction'],
#    'task_no_in_section': '5',
#    'starting_time': '26.92',
#    'ending_time': '31.98'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Eleusis 2.0', 'Environment', 1],
#    'section': ['Eleusis 2.0', 'Environment', 1, 'Introduction'],
#    'task_no_in_section': '4',
#    'starting_time': '19.62',
#    'ending_time': '26.92'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Eleusis 2.0', 'Environment', 1],
#    'section': ['Eleusis 2.0', 'Environment', 1, 'Conclusion'],
#    'task_no_in_section': '1',
#    'starting_time': '84.38',
#    'ending_time': '111.9'}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Eleusis 2.0/Environment/Session1/tasks.yaml', 'w') as f:
  yaml.safe_dump(tasks, f)

# %% [markdown]
# ## For Ljubljana and Rennes, there are no Sections, so we have skipped over this part

# %%
def findTaskNo(name):
  return name.split("Task")[1][0]

# %%
timeFiles_path = os.path.join(session_og_path, 'Tasks')
timeFiles = os.listdir(timeFiles_path)
tasks = []
model_name = 'biosignalsindex.Task'
for folder in section_folders:
  section_path = os.path.join(session_vis_path, folder)
  task_folders = os.listdir(section_path)
  for t_folder in task_folders:
    taskNo = findTaskNo(t_folder)
    timeFile = fnmatch.filter(timeFiles, 'timeTask{}*-{}*'.format(taskNo, folder))[0]
    df = pd.read_excel(os.path.join(timeFiles_path, timeFile), header=None)
    starting_time = df.iloc[0, 0]
    ending_time = df.iloc[-1, 0]
    task = {
        'model': model_name,
        'fields': {
          'session': [thematic_name, session_id],
          'section': [thematic_name, session_id, folder],
          'task_no_in_section': taskNo,
          'starting_time': str(round(starting_time, 2)),
          'ending_time': str(round(ending_time, 2))
        }
    }
    tasks.append(task)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 timeFiles_path = os.path.join(session_og_path, 'Tasks')
# ----> 2 timeFiles = os.listdir(timeFiles_path)
#       3 tasks = []
#       4 model_name = 'biosignalsindex.Task'
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/gina101/Session2/Tasks'

# %% [markdown]
# ## Modification of this script for the Ljubljana data

# %%
def findTaskNo(name):
  denominators = ["HR", "SC", "Temp"]
  for d in denominators:
    if d not in name:
      continue
    else:
      return name.split("Task")[1].split(d)[0]

tasks = []
task_nums = []
model_name = 'biosignalsindex.Task'
task_path = os.path.join(session_og_path, 'Tasks_XLSX')
task_folders = os.listdir(task_path)
for t_folder in task_folders:
  taskNo = findTaskNo(t_folder)
  if taskNo in task_nums:
    continue
  task_nums.append(taskNo)
  print('Processing task ', taskNo)
  df = pd.read_excel(os.path.join(task_path, t_folder))
  starting_time = int(df.iloc[0, 0])/60 # timestamps are in seconds
  ending_time = int(df.iloc[-1, 0])/60 # timestamps are in seconds
  task = {
      'model': model_name,
      'fields': {
        'session': [city_name, thematic_name, session_id],
        'task_no_in_section': taskNo,
        'starting_time': str(round(starting_time, 2)),
        'ending_time': str(round(ending_time, 2))
      }
  }
  tasks.append(task)
# Out:
# Processing task  6
# Processing task  1
# Processing task  4
# Processing task  5
# Processing task  2

# %%
tasks
# Out:
# [{'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Ljubljana', 'Environment', 2],
#    'task_no_in_section': '6',
#    'starting_time': '39.05',
#    'ending_time': '46.85'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Ljubljana', 'Environment', 2],
#    'task_no_in_section': '1',
#    'starting_time': '16.0',
#    'ending_time': '17.73'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Ljubljana', 'Environment', 2],
#    'task_no_in_section': '4',
#    'starting_time': '24.73',
#    'ending_time': '28.03'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Ljubljana', 'Environment', 2],
#    'task_no_in_section': '5',
#    'starting_time': '28.05',
#    'ending_time': '39.03'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Ljubljana', 'Environment', 2],
#    'task_no_in_section': '2',
#    'starting_time': '17.75',
#    'ending_time': '20.48'}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Ljubljana/Environment/Session2/tasks.yaml', 'w') as f:
  yaml.safe_dump(tasks, f)

# %% [markdown]
# ## Modifications for Rennes

# %%
def findTaskNo(name):
  denominators = ["HR", "SC", "Temp"]
  for d in denominators:
    if d not in name:
      continue
    else:
      return name.split("Task")[1].split(d)[0]

tasks = []
task_nums = []
model_name = 'biosignalsindex.Task'
# Since the other files have issues, we will read directly from the files for sensors 2 and 5 since we trust their frequency
wanted_suffixes = ("HR2.xlsx", "HR5.xlsx", "Temp2.xlsx", "Temp5.xlsx", "SC2.xlsx", "SC5.xlsx", "HR3.xlsx", "Temp3.xlsx", "SC3.xlsx", "HR6.xlsx", "Temp6.xlsx", "SC6.xlsx")
task_files = fnmatch.filter(os.listdir(session_og_path), 'Task*')
task_files = [f for f in task_files if any(f.endswith(suf) for suf in wanted_suffixes)]
print(task_files)
for t in task_files:
  taskNo = findTaskNo(t)
  if taskNo in task_nums:
    continue
  task_nums.append(taskNo)
  print('Processing task ', taskNo)
  df = pd.read_excel(os.path.join(session_og_path, t))
  starting_time = int(df.iloc[0, 1])/60000 # timestamps are in milliseconds
  print(starting_time)
  ending_time = int(df.iloc[-1, 1])/60000 # timestamps are in milliseconds
  print(ending_time)
  task = {
      'model': model_name,
      'fields': {
        'session': [city_name, thematic_name, session_id],
        'task_no_in_section': taskNo,
        'starting_time': str(round(starting_time, 2)),
        'ending_time': str(round(ending_time, 2))
      }
  }
  tasks.append(task)
# Out:
# ['Task8HR3.xlsx', 'Task7Temp3.xlsx', 'Task6Temp2.xlsx', 'Task7Temp2.xlsx', 'Task6Temp3.xlsx', 'Task8SC6.xlsx', 'Task6Temp6.xlsx', 'Task7SC5.xlsx', 'Task7SC3.xlsx', 'Task6SC5.xlsx', 'Task7HR6.xlsx', 'Task7Temp5.xlsx', 'Task6HR6.xlsx', 'Task7HR3.xlsx', 'Task8Temp3.xlsx', 'Task7SC2.xlsx', 'Task6SC2.xlsx', 'Task8SC5.xlsx', 'Task6SC6.xlsx', 'Task6HR3.xlsx', 'Task8SC2.xlsx', 'Task6SC3.xlsx', 'Task7HR5.xlsx', 'Task7Temp6.xlsx', 'Task6Temp5.xlsx', 'Task8HR5.xlsx', 'Task6HR5.xlsx', 'Task8Temp2.xlsx', 'Task8Temp6.xlsx', 'Task7HR2.xlsx', 'Task6HR2.xlsx', 'Task7SC6.xlsx', 'Task8HR2.xlsx', 'Task8Temp5.xlsx', 'Task8HR6.xlsx', 'Task8SC3.xlsx']
# Processing task  8
# 83.66671666666667
# 95.7666
# Processing task  7
# 68.93336666666667
# 83.66658333333334
# Processing task  6
# 51.31675
# 68.9333

# %%
tasks
# Out:
# [{'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Rennes', 'Environment', 2],
#    'task_no_in_section': '8',
#    'starting_time': '83.67',
#    'ending_time': '95.77'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Rennes', 'Environment', 2],
#    'task_no_in_section': '7',
#    'starting_time': '68.93',
#    'ending_time': '83.67'}},
#  {'model': 'biosignalsindex.Task',
#   'fields': {'session': ['Rennes', 'Environment', 2],
#    'task_no_in_section': '6',
#    'starting_time': '51.32',
#    'ending_time': '68.93'}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Rennes/Environment/Session2/tasks.yaml', 'w') as f:
  yaml.safe_dump(tasks, f)

# %% [markdown]
# # Generating fixtures for Superepisodes

# %% [markdown]
# ## Modification for Eleusis Data

# %%
times_path = '/home/gina101/Eleusis 2.0/Eleusis 2.0/Tasks'

# %%
ids_path = '/home/gina101/Eleusis 2.0/Eleusis 2.0/IDs'

# %%
def findSceneNo(name):
  if len(name.split("HR")) != 1:
    return name.split("HR")[0].split("Scene")[1]
  elif len(name.split("SC")) != 1:
    return name.split("SC")[0].split("Scene")[1]
  elif len(name.split("Temp")) != 1:
    return name.split("Temp")[0].split("Scene")[1]

# %%
def findSensorNo(name):
  return name.split("Sensor")[1].split("-")[0]

# %%
def findSection(name):
  return name.split("-")[1]

# %%
def findTaskNo(name):
  return name.split("-")[2].split(".xlsx")[0]

# %%
ids = os.listdir(ids_path)
# scenes = []
# for f in ids:
#   no = findSceneNo(f)
#   if no not in scenes:
#     scenes.append(no)
# scenes

# %%
# scenes = [15, 18, 25, 36, 41, 50, 54, 81, 117, 119, 123, 161]
scenes = [76]

# %% [markdown]
# Checking to see whether a scene is split up between two tasks.

# %%
# Code to order tasks
def ordertasks(files):
  [fileA, fileB] = files
  sectionA = fileA.split("-")[0]
  sectionB = fileB.split("-")[0]
  if sectionA == sectionB:
    # It's down to task number
    taskA = fileA.split("-")[1]
    taskB = fileB.split("-")[1]
    return [fileA, fileB] if taskA < taskB else [fileB, fileA]
  else:
    match sectionA:
      case "Introduction":
        # Then task A is definitely before task B
        return [fileA, fileB]
      case "Conclusion":
        # Then task B is definitely before task A
        return [fileB, fileA]
      case _:
        match sectionB:
          case "Introduction":
            return [fileB, fileA]
          case "Conclusion":
            return [fileA, fileB]
          case _:
            sectionA_no=sectionA.split()[1]
            sectionB_no=sectionB.split()[1]
            return [fileA, fileB] if sectionA_no < sectionB_no else [fileB, fileA]

# %%
def findSectionAndTask(f):
  section = f.split("-")[1]
  task = f.split("-")[2].split(".xlsx")[0]
  return '{}-{}'.format(section, task)

# %%
# A lot of files in session 3 of the sociodrama seemed to be duplicates of each other
# they seemed to have the same content
# hence the following line, because their names were 'file x', 'file x (1)'
split_scenes = {}
ids_duplicated = set(fnmatch.filter(ids, "*(1).xlsx"))
ids_filtered = set(ids) - set(ids_duplicated)
# My so far criteria for splitting is incorrect
for scene in scenes:
  string = "(idScene{})(?!\d)".format(scene)
  files = [f for f in ids_filtered if re.match(string, f)]
  tasks = set()
  for f in files:
    task = findSectionAndTask(f)
    tasks.add(task)
  if len(tasks) > 1:
    print("Scene ", scene)
    print(tasks)
    ordered_tasks = ordertasks(list(tasks))
    split_scenes[int(scene)] = ordered_tasks
    print(ordered_tasks)
# Out:
# Scene  21
# {'Section 2-3', 'Section 2-2'}
# ['Section 2-2', 'Section 2-3']
# Scene  105
# {'Section 4-1', 'Section 3-3'}
# ['Section 3-3', 'Section 4-1']

# %%
scene_axis_mappings = {
  9: [6],
  12: [1],
  13: [3],
  14: [1],
  15: [1],
  16: [3] ,
  21: [3],
  29: [6],
  32: [6],
  37: [5],
  39: [2],
  105: [5]
}

# %% [markdown]
# Case where scene is not split up between tasks

# %%
axis = 1

# %%
simple_scene_fixtures = []
model_names = ['biosignalsindex.Scene', 'biosignalsindex.SceneInTaskMetadata']

# diff = set(scene_axis_mappings.keys()) - set(split_scenes.keys())

# dupes = set(fnmatch.filter(ids, "* (1).*"))
# ids_filtered = set(ids) - set(dupes)
ids = os.listdir(ids_path)
# for scene in diff:
for scene in scenes:
  print("scene ", scene)
  # A lot of files in session 3 of the sociodrama seemed to be duplicates of each other
  # they seemed to have the same content
  # hence the following line, because their names were 'file x', 'file x (1)'
  # string = "(idScene{})(?!\d)".format(scene)
  # files = [f for f in ids_filtered if re.match(string, f)]
  files = fnmatch.filter(ids, "idScene{}*-*.xlsx".format(scene))
  print(files)
  frames = []
  min = 500000
  max = 0
  for f in files:
    frame = pd.read_excel(os.path.join(ids_path, f), header=None)
    if frame.iloc[0, 0] == 1:
      continue # These are wrong IDs
    if frame.iloc[0, 0] < min:
      min = frame.iloc[0, 0]
    if frame.iloc[1, 0] > max:
      max = frame.iloc[1, 0]

  section_name = findSection(files[0])
  task_no = findTaskNo(files[0])

  time_files = fnmatch.filter(os.listdir(times_path), 'timeTask{}*-{}.xlsx'.format(task_no, section_name))
  min_starting_time = 300
  max_ending_time = 0
  for f in time_files:
    time_frame = pd.read_excel(os.path.join(times_path, f), header=None)
    starting_time = time_frame.iloc[min, 0]
    if max > len(time_frame):
      print("Warning: max ", max, " is greater than length of time_frame ", len(time_frame), " in file ", f)
      max = len(time_frame) - 1
    ending_time = time_frame.iloc[max, 0]
    if starting_time < min_starting_time:
      min_starting_time = starting_time
    if ending_time > max_ending_time:
      max_ending_time = ending_time

  scene_fixture = {
      'model': model_names[0],
      'fields': {
          'scene_id_in_session': scene,
          'is_superepisode': True,
          'session': [city_name, thematic_name, session_id],
          'axis': [[city_name, thematic_name, axis]],
          'starting_time': str(round(min_starting_time, 2)),
          'ending_time': str(round(max_ending_time, 2)),
      }
  }

  metadata_fixture = {
      'model': model_names[1],
      'fields': {
          'task': [city_name, thematic_name, session_id, section_name, int(task_no)],
          'scene': [city_name, thematic_name, session_id, scene],
          'task_order': 1,
          'starting_row': str(min),
          'ending_row': str(max)
      }
  }
  simple_scene_fixtures.append(scene_fixture)
  simple_scene_fixtures.append(metadata_fixture)
# Out:
# scene  76
# ['idScene76SCSensor4-Main-3.xlsx', 'idScene76TempSensor5-Main-4.xlsx', 'idScene76HRSensor6-Main-3.xlsx', 'idScene76SCSensor5-Main-3.xlsx', 'idScene76HRSensor4-Main-4.xlsx', 'idScene76TempSensor3-Main-3.xlsx']
# Warning: max  89693  is greater than length of time_frame  89676  in file  timeTask3TempSensor3-Main.xlsx
# Warning: max  89675  is greater than length of time_frame  89636  in file  timeTask3SCSensor4-Main.xlsx

# %%
simple_scene_fixtures
# Out:
# [{'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': 76,
#    'is_superepisode': True,
#    'session': ['Eleusis 2.0', 'Environment', 1],
#    'axis': [['Eleusis 2.0', 'Environment', 1]],
#    'starting_time': '70.66',
#    'ending_time': '71.67'}},
#  {'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Eleusis 2.0', 'Environment', 1, 'Main', 3],
#    'scene': ['Eleusis 2.0', 'Environment', 1, 76],
#    'task_order': 1,
#    'starting_row': '81987',
#    'ending_row': '89635'}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Eleusis 2.0/Environment/Session1/scene_76.yaml', 'w') as f:
  yaml.safe_dump(simple_scene_fixtures, f)

# %% [markdown]
# Case where scene is split up between tasks

# %%
# A lot of files in session 3 of the sociodrama seemed to be duplicates of each other
# they seemed to have the same content
# hence the following line, because their names were 'file x', 'file x (1)'
dupes = set(fnmatch.filter(ids, "* (1).*"))
ids_filtered = set(ids) - set(dupes)

split_scene_fixtures = []
split_scene_metadata_fixtures = []
model_names = ['biosignalsindex.Scene', 'biosignalsindex.SceneInTaskMetadata']
for scene in split_scenes.keys():
  string = "(idScene{})(?!\d)".format(scene)
  files = [f for f in ids_filtered if re.match(string, f)]
  min_starting_time = 300
  max_ending_time = 0

  for index, task in enumerate(split_scenes[scene]):
    section_name = task.split("-")[0]
    task_no = task.split("-")[1]
    task_files = fnmatch.filter(files, "*{}.*".format(task))
    frames = []
    min = 500000
    max = 0
    for f in task_files:
      frame = pd.read_excel(os.path.join(ids_path, f), header=None)
      if frame.iloc[0, 0] < min:
        min = frame.iloc[0, 0]
      if frame.iloc[1, 0] > max:
        max = frame.iloc[1, 0]

    time_files = fnmatch.filter(os.listdir(times_path), 'timeTask{}*-{}.xlsx'.format(task_no, section_name))
    for f in time_files:
      time_frame = pd.read_excel(os.path.join(times_path, f), header=None)
      starting_time = time_frame.iloc[min, 0]
      if len(time_frame) <= max:
        max = len(time_frame) - 1
      ending_time = time_frame.iloc[max, 0]
      if index == 0 and starting_time < min_starting_time:
        min_starting_time = starting_time
      elif index == 1 and ending_time > max_ending_time:
        max_ending_time = ending_time

    metadata_fixture = {
        'model': model_names[1],
        'fields': {
            'task': [thematic_name, session_id, section_name, int(task_no)],
            'scene': [thematic_name, session_id, scene],
            'task_order': index + 1,
            'starting_row': str(min),
            'ending_row': str(max)
        }
    }

    split_scene_metadata_fixtures.append(metadata_fixture)


  scene_fixture = {
      'model': model_names[0],
      'fields': {
          'scene_id_in_session': scene,
          'is_superepisode': True,
          'session': [thematic_name, session_id],
          'axis': [[thematic_name, a] for a in scene_axis_mappings[scene]],
          'starting_time': str(round(min_starting_time, 2)),
          'ending_time': str(round(max_ending_time, 2)),
      }
  }

  split_scene_fixtures.append(scene_fixture)

# %%
split_scene_fixtures
# Out:
# [{'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': 21,
#    'is_superepisode': True,
#    'session': ['Immigration', 2],
#    'axis': [['Immigration', 3]],
#    'starting_time': '27.5',
#    'ending_time': '29.34'}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': 105,
#    'is_superepisode': True,
#    'session': ['Immigration', 2],
#    'axis': [['Immigration', 5]],
#    'starting_time': '56.22',
#    'ending_time': '56.75'}}]

# %%
split_scene_metadata_fixtures
# Out:
# [{'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Immigration', 2, 'Section 2', 2],
#    'scene': ['Immigration', 2, 21],
#    'task_order': 1,
#    'starting_row': '123750',
#    'ending_row': '134752'}},
#  {'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Immigration', 2, 'Section 2', 3],
#    'scene': ['Immigration', 2, 21],
#    'task_order': 2,
#    'starting_row': '1',
#    'ending_row': '2944'}},
#  {'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Immigration', 2, 'Section 3', 3],
#    'scene': ['Immigration', 2, 105],
#    'task_order': 1,
#    'starting_row': '25848',
#    'ending_row': '29413'}},
#  {'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Immigration', 2, 'Section 4', 1],
#    'scene': ['Immigration', 2, 105],
#    'task_order': 2,
#    'starting_row': '1',
#    'ending_row': '512'}}]

# %% [markdown]
# ## Modification for Ljubljana data

# %%
ids_path = '/home/gina101/Session2/Scene_IDs_XLSX'
tasks_path = '/home/gina101/Session2/Tasks_XLSX'

# %%
def getSensorType(name):
  if "HR" in name:
    return "HR"
  elif "SC" in name:
    return "SC"
  elif "Temp" in name:
    return "Temp"

# %%
def findSceneNo(name):
  sensorType = getSensorType(name)
  if sensorType is not None:
    return name.split("Scene")[1].split(sensorType)[0]

# %%
def findTaskNo(name):
  sensorType = getSensorType(name)
  if sensorType is not None:
    return name.split("Task")[1].split(sensorType)[0].split(".xlsx")[0]

# %%
simple_scene_fixtures = []
metadata_fixtures = []
model_names = ['biosignalsindex.Scene', 'biosignalsindex.SceneInTaskMetadata']
ids = os.listdir(ids_path)
processed_scenes = []
task_files = os.listdir(task_path)

for id in ids:
  scene = findSceneNo(id)
  if scene in processed_scenes:
    continue
  processed_scenes.append(scene)
  print("Processing scene ", scene)

  id_file = pd.read_excel(os.path.join(ids_path, id), header=None)
  starting_time = id_file.iloc[0, 0]
  ending_time = id_file.iloc[-1, 0]

  start_in_minutes = starting_time/60
  end_in_minutes = ending_time/60

  scene_fixture = {
      'model': model_names[0],
      'fields': {
          'scene_id_in_session': scene,
          'is_superepisode': True,
          'session': [city_name, thematic_name, session_id],
          'axis': [[city_name, thematic_name, 1]],
          'starting_time': float(round(start_in_minutes, 2)),
          'ending_time': float(round(end_in_minutes, 2)),
      }
  }

  task_num = findTaskNo(id)
  min = 5000000
  max = 0
  # open a task file for the corresponding task
  task = fnmatch.filter(task_files, f"Task{task_num}*")[0]
  print("Using this file as reference: ", task)
  task_frame = pd.read_excel(os.path.join(tasks_path, task)) # we only need one of these to find out where it starts
  # Find the first line where you can see the timestamp in starting_time (at least the non floating point part)
  start_index_series = task_frame[task_frame.iloc[:, 0].astype(int) == starting_time.astype(int)].index
  if start_index_series.empty:
    print("Start index empty")
  end_index_series = task_frame[task_frame.iloc[:, 0].astype(int) == ending_time.astype(int)].index
  if end_index_series.empty:
    print("End index empty")

  metadata_fixture = {
      'model': model_names[1],
      'fields': {
          'task': [city_name, thematic_name, session_id, int(task_num)],
          'scene': [city_name, thematic_name, session_id, int(scene)],
          'task_order': 1,
          'starting_row': int(start_index_series[0]),
          'ending_row': int(end_index_series[0])
      }
  }
  simple_scene_fixtures.append(scene_fixture)
  metadata_fixtures.append(metadata_fixture)
# Out:
# Task files considered:  ['Task5Temp2.xlsx', 'Task12Temp5.xlsx', 'Task12SC2.xlsx', 'Task12HR2.xlsx', 'Task5SC2.xlsx', 'Task5HR5.xlsx', 'Task12Temp2.xlsx', 'Task11Temp5.xlsx', 'Task11Temp2.xlsx', 'Task11SC5.xlsx', 'Task11SC2.xlsx', 'Task11HR2.xlsx', 'Task5Temp5.xlsx', 'Task11HR5.xlsx', 'Task5HR2.xlsx', 'Task12HR5.xlsx', 'Task5SC5.xlsx', 'Task12SC5.xlsx']
# Processing scene  1
# Corresponding task number:  5
# Using this file as reference:  Task5Temp2.xlsx
# Start index found at 15740 (value=1944000.335693359, diff=0.3356933589093387) for Task5Temp2.xlsx
# End index found at 24666 (value=2014000.366210938, diff=0.3662109379656613) for Task5Temp2.xlsx
# Processing scene  2
# Corresponding task number:  5
# Using this file as reference:  Task5Temp2.xlsx
# Start index found at 26202 (value=2026000.366210938, diff=0.3662109379656613) for Task5Temp2.xlsx
# End index found at 40147 (value=2134992.584228516, diff=7.415771483909339) for Task5Temp2.xlsx
# Processing scene  4
# Corresponding task number:  11
# Using this file as reference:  Task11Temp5.xlsx
# Start index found at 142444 (value=4263997.230712891, diff=2.769287109375) for Task11Temp5.xlsx
# End index found at 149484 (value=4318997.032470703, diff=2.967529296875) for Task11Temp5.xlsx
# Processing scene  3
# Corresponding task number:  11
# Using this file as reference:  Task11Temp5.xlsx
# Start index found at 126852 (value=4141997.670166016, diff=2.3298339839093387) for Task11Temp5.xlsx
# End index found at 130948 (value=4173997.554931641, diff=2.4450683589093387) for Task11Temp5.xlsx
# Processing scene  6
# Corresponding task number:  12
# Using this file as reference:  Task12Temp5.xlsx
# Start index found at 105642 (value=5336001.2734375, diff=1.2734375) for Task12Temp5.xlsx
# End index found at 108330 (value=5357001.197998047, diff=1.197998046875) for Task12Temp5.xlsx
# Processing scene  5
# Corresponding task number:  12
# Using this file as reference:  Task12Temp5.xlsx
# Start index found at 101548 (value=5304001.358154297, diff=1.358154296875) for Task12Temp5.xlsx
# End index found at 104746 (value=5329001.298828125, diff=1.298828125) for Task12Temp5.xlsx

# %%
simple_scene_fixtures
# Out:
# [{'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '1',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 1],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 32400.0,
#    'ending_time': 33566.67}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '2',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 1],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 33766.67,
#    'ending_time': 35583.33}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '4',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 1],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 71066.67,
#    'ending_time': 71983.33}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '3',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 1],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 69033.33,
#    'ending_time': 69566.67}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '6',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 1],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 88933.33,
#    'ending_time': 89283.33}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '5',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 1],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 88400.0,
#    'ending_time': 88816.67}}]

# %%
metadata_fixtures
# Out:
# [{'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Rennes', 'Environment', 1, 5],
#    'scene': ['Rennes', 'Environment', 1, 1],
#    'task_order': 1,
#    'starting_row': 15740,
#    'ending_row': 24666}},
#  {'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Rennes', 'Environment', 1, 5],
#    'scene': ['Rennes', 'Environment', 1, 2],
#    'task_order': 1,
#    'starting_row': 26202,
#    'ending_row': 40147}},
#  {'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Rennes', 'Environment', 1, 11],
#    'scene': ['Rennes', 'Environment', 1, 4],
#    'task_order': 1,
#    'starting_row': 142444,
#    'ending_row': 149484}},
#  {'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Rennes', 'Environment', 1, 11],
#    'scene': ['Rennes', 'Environment', 1, 3],
#    'task_order': 1,
#    'starting_row': 126852,
#    'ending_row': 130948}},
#  {'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Rennes', 'Environment', 1, 12],
#    'scene': ['Rennes', 'Environment', 1, 6],
#    'task_order': 1,
#    'starting_row': 105642,
#    'ending_row': 108330}},
#  {'model': 'biosignalsindex.SceneInTaskMetadata',
#   'fields': {'task': ['Rennes', 'Environment', 1, 12],
#    'scene': ['Rennes', 'Environment', 1, 5],
#    'task_order': 1,
#    'starting_row': 101548,
#    'ending_row': 104746}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Ljubljana/Environment/Session2/superepisodes.yaml', 'w') as f:
  yaml.safe_dump(simple_scene_fixtures, f)
  # yaml.dump(scene_fixtures, f)

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Ljubljana/Environment/Session2/superepisode_metadata.yaml', 'w') as f:
  yaml.safe_dump(metadata_fixtures, f)
  # yaml.dump(scene_fixtures, f)

# %% [markdown]
# ## Modification for Rennes

# %%
# def findSceneNo(name):
#   return name.split("_")[0].split("Scene")[1]

def findSceneNo(name):
  denominators = ["HR", "SC", "Temp"]
  for d in denominators:
    if d not in name:
      continue
    else:
      return name.split("Scene")[1].split(d)[0]

# %%
def findTaskNo(name):
  return name.split("Task")[1].split(".xlsx")[0]

# %%
simple_scene_fixtures = []
metadata_fixtures = []
model_names = ['biosignalsindex.Scene', 'biosignalsindex.SceneInTaskMetadata']
wanted_suffixes = ("HR2.xlsx", "HR5.xlsx", "HR3.xlsx", "HR6.xlsx", "Temp2.xlsx", "Temp5.xlsx", "Temp3.xlsx","Temp6.xlsx", "SC2.xlsx", "SC5.xlsx", "SC3.xlsx", "SC6.xlsx")
ids = fnmatch.filter(os.listdir(session_og_path), "idScene*")
id_files = [f for f in ids if any(f.endswith(suf) for suf in wanted_suffixes)]
processed_scenes = []
task_files = fnmatch.filter(os.listdir(session_og_path), "Task*")
task_files = [f for f in task_files if any(f.endswith(suf) for suf in wanted_suffixes)]
print("Task files considered: ", task_files
      )
for id in ids:
  scene = findSceneNo(id)
  if scene in processed_scenes:
    continue
  processed_scenes.append(scene)
  print("Processing scene ", scene)

  id_file = pd.read_excel(os.path.join(session_og_path, id), header=None)
  starting_time = id_file.iloc[0, 0]
  ending_time = id_file.iloc[-1, 0]

  start_in_minutes = float(starting_time)/60 # milliseconds to minutes
  end_in_minutes = float(ending_time)/60 # milliseconds to minutes

  scene_fixture = {
      'model': model_names[0],
      'fields': {
          'scene_id_in_session': scene,
          'is_superepisode': True,
          'session': [city_name, thematic_name, session_id],
          'axis': [[city_name, thematic_name, 1]],
          'starting_time': float(round(start_in_minutes, 2)),
          'ending_time': float(round(end_in_minutes, 2)),
      }
  }

  task_num = findTaskNo(id)
  print("Corresponding task number: ", task_num)
  min = 5000000
  max = 0
  # open a task file for the corresponding task
  task = fnmatch.filter(task_files, f"Task{task_num}*")[0]
  print("Using this file as reference: ", task)
  task_frame = pd.read_excel(os.path.join(session_og_path, task)) # we only need one of these to find out where it starts
  # # Find the first line where you can see the timestamp in starting_time (at least the non floating point part)
  # start_index_series = task_frame[task_frame.iloc[:, 0].astype(int) == starting_time.astype(int)].index
  # if start_index_series.empty:
  #   print("Start index empty")
  # end_index_series = task_frame[task_frame.iloc[:, 0].astype(int) == ending_time.astype(int)].index
  # if end_index_series.empty:
  #   print("End index empty")


  # Convert the second column of df_task to integer type for comparison
  # Use a tolerance to find the nearest timestamp when exact matches don't exist
  col = task_frame.iloc[:, 1].astype(float)
  tol = 10  # adjust this tolerance as needed (same units as timestamps)

  # find nearest index for start timestamp
  start_diff = (col - float(starting_time)).abs()
  start_idx = start_diff.idxmin()
  if start_diff.loc[start_idx] <= tol:
    start_index_series = pd.Index([start_idx])
    print(f"Start index found at {start_idx} (value={col.loc[start_idx]}, diff={start_diff.loc[start_idx]}) for {task}")
  else:
    start_index_series = pd.Index([])
    print(f"Start index not found within tolerance {tol} for {task}, nearest diff={start_diff.loc[start_idx]}")

  # find nearest index for end timestamp
  end_diff = (col - float(ending_time)).abs()
  end_idx = end_diff.idxmin()
  if end_diff.loc[end_idx] <= tol:
    end_index_series = pd.Index([end_idx])
    print(f"End index found at {end_idx} (value={col.loc[end_idx]}, diff={end_diff.loc[end_idx]}) for {task}")
  else:
    end_index_series = pd.Index([])
    print(f"End index not found within tolerance {tol} for {task}, nearest diff={end_diff.loc[end_idx]}")

  metadata_fixture = {
      'model': model_names[1],
      'fields': {
          'task': [city_name, thematic_name, session_id, int(task_num)],
          'scene': [city_name, thematic_name, session_id, int(scene)],
          'task_order': 1,
          'starting_row': int(start_index_series[0]),
          'ending_row': int(end_index_series[0])
      }
  }
  simple_scene_fixtures.append(scene_fixture)
  metadata_fixtures.append(metadata_fixture)
# Out:
# Task files considered:  ['Task8HR3.xlsx', 'Task7Temp3.xlsx', 'Task6Temp2.xlsx', 'Task7Temp2.xlsx', 'Task6Temp3.xlsx', 'Task8SC6.xlsx', 'Task6Temp6.xlsx', 'Task7SC5.xlsx', 'Task7SC3.xlsx', 'Task6SC5.xlsx', 'Task7HR6.xlsx', 'Task7Temp5.xlsx', 'Task6HR6.xlsx', 'Task7HR3.xlsx', 'Task8Temp3.xlsx', 'Task7SC2.xlsx', 'Task6SC2.xlsx', 'Task8SC5.xlsx', 'Task6SC6.xlsx', 'Task6HR3.xlsx', 'Task8SC2.xlsx', 'Task6SC3.xlsx', 'Task7HR5.xlsx', 'Task7Temp6.xlsx', 'Task6Temp5.xlsx', 'Task8HR5.xlsx', 'Task6HR5.xlsx', 'Task8Temp2.xlsx', 'Task8Temp6.xlsx', 'Task7HR2.xlsx', 'Task6HR2.xlsx', 'Task7SC6.xlsx', 'Task8HR2.xlsx', 'Task8Temp5.xlsx', 'Task8HR6.xlsx', 'Task8SC3.xlsx']
# Processing scene  3
# Corresponding task number:  7
# Using this file as reference:  Task7Temp3.xlsx
# Start index found at 66779 (value=4658003.099609375, diff=3.099609375) for Task7Temp3.xlsx
# End index found at 71386 (value=4694003.133300781, diff=3.13330078125) for Task7Temp3.xlsx
# Processing scene  2
# Corresponding task number:  7
# Using this file as reference:  Task7Temp3.xlsx
# Start index found at 47067 (value=4504002.956054688, diff=2.9560546884313226) for Task7Temp3.xlsx
# End index found at 51803 (value=4541002.990478516, diff=2.990478515625) for Task7Temp3.xlsx
# Processing scene  5
# Corresponding task number:  8
# Using this file as reference:  Task8HR3.xlsx
# Start index found at 59618 (value=5486003.872558594, diff=3.87255859375) for Task8HR3.xlsx
# End index found at 64097 (value=5521003.905273438, diff=3.9052734384313226) for Task8HR3.xlsx
# Processing scene  1
# Corresponding task number:  6
# Using this file as reference:  Task6Temp2.xlsx
# Start index found at 4607 (value=3114998.138427734, diff=1.8615722660906613) for Task6Temp2.xlsx
# End index found at 8959 (value=3148998.138427734, diff=1.8615722660906613) for Task6Temp2.xlsx
# Processing scene  4
# Corresponding task number:  8
# Using this file as reference:  Task8HR3.xlsx
# Start index found at 57826 (value=5472003.859619141, diff=3.859619140625) for Task8HR3.xlsx
# End index found at 59490 (value=5485003.871826172, diff=3.871826171875) for Task8HR3.xlsx
# Processing scene  6
# Corresponding task number:  8
# Using this file as reference:  Task8HR3.xlsx
# Start index found at 71647 (value=5579996.178466797, diff=3.821533203125) for Task8HR3.xlsx
# End index found at 81373 (value=5655996.249267578, diff=3.750732421875) for Task8HR3.xlsx

# %%
simple_scene_fixtures
# Out:
# [{'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '3',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 2],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 77633.33,
#    'ending_time': 78233.33}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '2',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 2],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 75066.67,
#    'ending_time': 75683.33}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '5',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 2],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 91433.33,
#    'ending_time': 92016.67}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '1',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 2],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 51916.67,
#    'ending_time': 52483.33}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '4',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 2],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 91200.0,
#    'ending_time': 91416.67}},
#  {'model': 'biosignalsindex.Scene',
#   'fields': {'scene_id_in_session': '6',
#    'is_superepisode': True,
#    'session': ['Rennes', 'Environment', 2],
#    'axis': [['Rennes', 'Environment', 1]],
#    'starting_time': 93000.0,
#    'ending_time': 94266.67}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Rennes/Environment/Session2/superepisodes.yaml', 'w') as f:
  yaml.safe_dump(simple_scene_fixtures, f)
  # yaml.dump(scene_fixtures, f)

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Rennes/Environment/Session2/superepisode_metadata.yaml', 'w') as f:
  yaml.safe_dump(metadata_fixtures, f)
  # yaml.dump(scene_fixtures, f)

# %% [markdown]
# # Generating fixtures for files

# %% [markdown]
# ## Generating fixtures for task files

# %% [markdown]
# ### Eleusis

# %%
session_task_files_path = '/home/gina101/new_data/Eleusis 2.0/Environment/Session1/Visualizations'

# %%
def findSensorNo(name):
  return name.split("-")[0].split("Sensor")[1]

# %%
sections = os.listdir(session_task_files_path)
files_fixtures = []
model_name = 'biosignalsindex.File'
for section_folder in sections:
  section_path = os.path.join(session_task_files_path, section_folder)
  tasks = os.listdir(section_path)
  for task_folder in tasks:
    task_path = os.path.join(section_path, task_folder)
    files = os.listdir(task_path)
    for f in files:
      new_path = os.path.join(task_path, f).split("new_data/")[1]
      fixture = {
          'model': model_name,
          'fields': {
              'path': new_path,
              'participant': [city_name, thematic_name, session_id, findSensorNo(f)],
              'task': [city_name, thematic_name, session_id, section_folder, task_folder.split("Task")[1]]
          }
      }
      files_fixtures.append(fixture)

# %%
files_fixtures
# Out:
# [{'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task2/Task2AllSensor4-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '2']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task2/Task2AllSensor2-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '2'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '2']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task2/Task2AllSensor3-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '2']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task2/Task2AllSensor6-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '2']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task2/Task2AllSensor5-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '2']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task1/Task1AllSensor6-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '1']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task1/Task1AllSensor4-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '1']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task1/Task1AllSensor5-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '1']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task1/Task1AllSensor2-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '2'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '1']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task1/Task1AllSensor3-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '1']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task5/Task5AllSensor2-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '2'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task5/Task5AllSensor6-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task5/Task5AllSensor3-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task5/Task5AllSensor4-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task5/Task5AllSensor5-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task3/Task3AllSensor6-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '3']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task3/Task3AllSensor3-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '3']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task3/Task3AllSensor2-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '2'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '3']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task3/Task3AllSensor4-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '3']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task3/Task3AllSensor5-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '3']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task4/Task4AllSensor2-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '2'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task4/Task4AllSensor6-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task4/Task4AllSensor3-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task4/Task4AllSensor5-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Main/Task4/Task4AllSensor4-Main.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task5/Task5AllSensor3-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task5/Task5AllSensor2-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '2'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task5/Task5AllSensor6-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task5/Task5AllSensor5-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task5/Task5AllSensor4-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '5']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task4/Task4AllSensor4-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task4/Task4AllSensor5-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task4/Task4AllSensor3-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task4/Task4AllSensor6-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Introduction/Task4/Task4AllSensor2-Introduction.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '2'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Introduction', '4']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Conclusion/Task1/Task1AllSensor4-Conclusion.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Conclusion', '1']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Conclusion/Task1/Task1AllSensor6-Conclusion.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Conclusion', '1']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Conclusion/Task1/Task1AllSensor5-Conclusion.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Conclusion', '1']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Conclusion/Task1/Task1AllSensor2-Conclusion.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '2'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Conclusion', '1']}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Eleusis 2.0/Environment/Session1/Visualizations/Conclusion/Task1/Task1AllSensor3-Conclusion.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Conclusion', '1']}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Eleusis 2.0/Environment/Session1/scene_files.yaml', 'w') as f:
  yaml.safe_dump(files_fixtures, f)

# %% [markdown]
# ### Ljubljana

# %%
session_task_files_path = '/home/gina101/new_data/Ljubljana/Environment/Session2/Visualizations'

# %%
def findSensorNo(name):
  return name.split("Sensor")[1].split(".csv")[0]

# %%
files_fixtures = []
model_name = 'biosignalsindex.File'
city_name = 'Ljubljana'
tasks = os.listdir(session_task_files_path)
for task_folder in tasks:
  task_path = os.path.join(session_task_files_path, task_folder)
  files = os.listdir(task_path)
  for f in files:
    new_path = os.path.join(task_path, f).split("new_data/")[1]
    fixture = {
        'model': model_name,
        'fields': {
            'path': new_path,
            'participant': [city_name, thematic_name, session_id, int(findSensorNo(f))],
            'task': [city_name, thematic_name, session_id, int(task_folder.split("Task")[1])]
        }
    }
    files_fixtures.append(fixture)

# %%
files_fixtures
# Out:
# [{'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task2/Task2AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'task': ['Ljubljana', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task2/Task2AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'task': ['Ljubljana', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task2/Task2AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'task': ['Ljubljana', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task2/Task2AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'task': ['Ljubljana', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task6/Task6AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'task': ['Ljubljana', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task6/Task6AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'task': ['Ljubljana', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task6/Task6AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'task': ['Ljubljana', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task6/Task6AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'task': ['Ljubljana', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task1/Task1AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'task': ['Ljubljana', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task1/Task1AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'task': ['Ljubljana', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task1/Task1AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'task': ['Ljubljana', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task1/Task1AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'task': ['Ljubljana', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task5/Task5AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'task': ['Ljubljana', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task5/Task5AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'task': ['Ljubljana', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task5/Task5AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'task': ['Ljubljana', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task5/Task5AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'task': ['Ljubljana', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task4/Task4AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'task': ['Ljubljana', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task4/Task4AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'task': ['Ljubljana', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task4/Task4AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'task': ['Ljubljana', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Ljubljana/Environment/Session2/Visualizations/Task4/Task4AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'task': ['Ljubljana', 'Environment', 2, 4]}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Ljubljana/Environment/Session2/task_files.yaml', 'w') as f:
  yaml.safe_dump(files_fixtures, f)

# %% [markdown]
# ### Modification for Rennes

# %%
session_task_files_path = '/home/gina101/new_data/Rennes/Environment/Session2/Visualizations'

# %%
def findSensorNo(name):
  return name.split("Sensor")[1].split(".csv")[0]

# %%
files_fixtures = []
model_name = 'biosignalsindex.File'
city_name = 'Rennes'
tasks = os.listdir(session_task_files_path)
for task_folder in tasks:
  task_path = os.path.join(session_task_files_path, task_folder)
  files = os.listdir(task_path)
  for f in files:
    new_path = os.path.join(task_path, f).split("new_data/")[1]
    fixture = {
        'model': model_name,
        'fields': {
            'path': new_path,
            'participant': [city_name, thematic_name, session_id, int(findSensorNo(f))],
            'task': [city_name, thematic_name, session_id, int(task_folder.split("Task")[1])]
        }
    }
    files_fixtures.append(fixture)

# %%
files_fixtures
# Out:
# [{'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task6/Task6AllSensor5.csv',
#    'participant': ['Rennes', 'Environment', 2, 5],
#    'task': ['Rennes', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task6/Task6AllSensor6.csv',
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'task': ['Rennes', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task6/Task6AllSensor3.csv',
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'task': ['Rennes', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task6/Task6AllSensor2.csv',
#    'participant': ['Rennes', 'Environment', 2, 2],
#    'task': ['Rennes', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task7/Task7AllSensor2.csv',
#    'participant': ['Rennes', 'Environment', 2, 2],
#    'task': ['Rennes', 'Environment', 2, 7]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task7/Task7AllSensor6.csv',
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'task': ['Rennes', 'Environment', 2, 7]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task7/Task7AllSensor3.csv',
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'task': ['Rennes', 'Environment', 2, 7]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task7/Task7AllSensor5.csv',
#    'participant': ['Rennes', 'Environment', 2, 5],
#    'task': ['Rennes', 'Environment', 2, 7]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task8/Task8AllSensor6.csv',
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'task': ['Rennes', 'Environment', 2, 8]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task8/Task8AllSensor2.csv',
#    'participant': ['Rennes', 'Environment', 2, 2],
#    'task': ['Rennes', 'Environment', 2, 8]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task8/Task8AllSensor3.csv',
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'task': ['Rennes', 'Environment', 2, 8]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'path': 'Rennes/Environment/Session2/Visualizations/Task8/Task8AllSensor5.csv',
#    'participant': ['Rennes', 'Environment', 2, 5],
#    'task': ['Rennes', 'Environment', 2, 8]}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Rennes/Environment/Session2/task_files.yaml', 'w') as f:
  yaml.safe_dump(files_fixtures, f)

# %% [markdown]
#  ## Generating fixtures for scene files

# %% [markdown]
# ### Eleusis

# %%
ids_path = '/home/gina101/Eleusis 2.0/Eleusis 2.0/IDs'

# %%
session_scene_files_path = '/home/gina101/new_data/Eleusis 2.0/Environment/Session1/Sonifications'

# %%
def findSceneNo(name):
  if len(name.split("HR")) != 1:
    return name.split("HR")[0].split("Scene")[1]
  elif len(name.split("SC")) != 1:
    return name.split("SC")[0].split("Scene")[1]
  elif len(name.split("Temp")) != 1:
    return name.split("Temp")[0].split("Scene")[1]

# %%
# scenes = [15, 18, 25, 36, 41, 50, 54, 81, 117, 119, 123, 161]
scenes = [76]

# %%
def findSensorNo(name):
  return name.split("Sensor")[1].split(".csv")[0]

# %%
session_scene_files_path = '/home/gina101/new_data/Eleusis 2.0/Environment/Session1/Sonifications'
sections = os.listdir(session_scene_files_path)
files_fixtures = []
model_name = 'biosignalsindex.File'

for scene in scenes:
  print('Processing scene ', scene)
  folder = 'Scene{}'.format(scene)
  path = os.path.join(session_scene_files_path, folder)
  sceneFiles = os.listdir(path)
  for file in sceneFiles:
    new_path = os.path.join(path, file).split("new_data/")[1]
    print('new path: ', new_path)
    fixture = {
        'model': model_name,
        'fields': {
            'id': None,
            'path': new_path,
            'participant': [city_name, thematic_name, session_id, findSensorNo(file)],
            'scene': [city_name, thematic_name, session_id, scene]
        }
    }
    files_fixtures.append(fixture)
# Out:
# Processing scene  76
# new path:  Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor6.csv
# new path:  Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor4.csv
# new path:  Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor2.csv
# new path:  Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor5.csv
# new path:  Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor3.csv

# %%
files_fixtures
# Out:
# [{'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor6.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'scene': ['Eleusis 2.0', 'Environment', 1, 76]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor4.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'scene': ['Eleusis 2.0', 'Environment', 1, 76]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor2.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '2'],
#    'scene': ['Eleusis 2.0', 'Environment', 1, 76]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor5.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'scene': ['Eleusis 2.0', 'Environment', 1, 76]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Eleusis 2.0/Environment/Session1/Sonifications/Scene76/Scene76AllSensor3.csv',
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'scene': ['Eleusis 2.0', 'Environment', 1, 76]}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Eleusis 2.0/Environment/Session1/scene_files_76.yaml', 'w') as f:
  yaml.safe_dump(files_fixtures, f)

# %% [markdown]
# ### Ljubljana

# %%
ids_path = '/home/gina101/Session2/Scene_IDs_XLSX'

# %%
session_scene_files_path = '/home/gina101/new_data/Ljubljana/Environment/Session2/Sonifications'

# %%
def findSceneNo(name):
  if len(name.split("HR")) != 1:
    return name.split("HR")[0].split("Scene")[1]
  elif len(name.split("SC")) != 1:
    return name.split("SC")[0].split("Scene")[1]
  elif len(name.split("Temp")) != 1:
    return name.split("Temp")[0].split("Scene")[1]

# %%
def findSensorNo(name):
  return int(name.split("Sensor")[1].split(".csv")[0])

# %%
scenes = [1,2,3,4,5,6]

# %%
files_fixtures = []
model_name = 'biosignalsindex.File'

for scene in scenes:
  scene_path = os.path.join(session_scene_files_path, f"Scene{scene}")
  files = os.listdir(scene_path)
  for f in files:
    new_path = os.path.join(scene_path, f).split("new_data/")[1]
    fixture = {
        'model': model_name,
        'fields': {
            'id': None,
            'path': new_path,
            'participant': [city_name, thematic_name, session_id, findSensorNo(f)],
            'scene': [city_name, thematic_name, session_id, scene]
        }
    }
    files_fixtures.append(fixture)

# %%
files_fixtures
# Out:
# [{'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene1/Scene1AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'scene': ['Ljubljana', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene1/Scene1AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'scene': ['Ljubljana', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene1/Scene1AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'scene': ['Ljubljana', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene1/Scene1AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'scene': ['Ljubljana', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene2/Scene2AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'scene': ['Ljubljana', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene2/Scene2AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'scene': ['Ljubljana', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene2/Scene2AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'scene': ['Ljubljana', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene2/Scene2AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'scene': ['Ljubljana', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene3/Scene3AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'scene': ['Ljubljana', 'Environment', 2, 3]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene3/Scene3AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'scene': ['Ljubljana', 'Environment', 2, 3]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene3/Scene3AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'scene': ['Ljubljana', 'Environment', 2, 3]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene3/Scene3AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'scene': ['Ljubljana', 'Environment', 2, 3]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene4/Scene4AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'scene': ['Ljubljana', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene4/Scene4AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'scene': ['Ljubljana', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene4/Scene4AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'scene': ['Ljubljana', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene4/Scene4AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'scene': ['Ljubljana', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene5/Scene5AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'scene': ['Ljubljana', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene5/Scene5AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'scene': ['Ljubljana', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene5/Scene5AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'scene': ['Ljubljana', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene5/Scene5AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'scene': ['Ljubljana', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene6/Scene6AllSensor1.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'scene': ['Ljubljana', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene6/Scene6AllSensor4.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'scene': ['Ljubljana', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene6/Scene6AllSensor3.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'scene': ['Ljubljana', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Ljubljana/Environment/Session2/Sonifications/Scene6/Scene6AllSensor2.csv',
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'scene': ['Ljubljana', 'Environment', 2, 6]}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Ljubljana/Environment/Session2/superepisode_scene_files.yaml', 'w') as f:
  yaml.safe_dump(files_fixtures, f)

# %% [markdown]
# ### Rennes

# %%
session_scene_files_path = '/home/gina101/new_data/Rennes/Environment/Session2/Sonifications'

# %%
def findSceneNo(name):
  if len(name.split("HR")) != 1:
    return name.split("HR")[0].split("Scene")[1]
  elif len(name.split("SC")) != 1:
    return name.split("SC")[0].split("Scene")[1]
  elif len(name.split("Temp")) != 1:
    return name.split("Temp")[0].split("Scene")[1]

# %%
def findSensorNo(name):
  return int(name.split("Sensor")[1].split(".csv")[0])

# %%
scenes = [1,2,3,4,5,6]

# %%
files_fixtures = []
model_name = 'biosignalsindex.File'

for scene in scenes:
  scene_path = os.path.join(session_scene_files_path, f"Scene{scene}")
  files = os.listdir(scene_path)
  for f in files:
    new_path = os.path.join(scene_path, f).split("new_data/")[1]
    fixture = {
        'model': model_name,
        'fields': {
            'id': None,
            'path': new_path,
            'participant': [city_name, thematic_name, session_id, findSensorNo(f)],
            'scene': [city_name, thematic_name, session_id, scene]
        }
    }
    files_fixtures.append(fixture)

# %%
files_fixtures
# Out:
# [{'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene1/Scene1AllSensor5.csv',
#    'participant': ['Rennes', 'Environment', 2, 5],
#    'scene': ['Rennes', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene1/Scene1AllSensor3.csv',
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'scene': ['Rennes', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene1/Scene1AllSensor2.csv',
#    'participant': ['Rennes', 'Environment', 2, 2],
#    'scene': ['Rennes', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene1/Scene1AllSensor6.csv',
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'scene': ['Rennes', 'Environment', 2, 1]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene2/Scene2AllSensor2.csv',
#    'participant': ['Rennes', 'Environment', 2, 2],
#    'scene': ['Rennes', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene2/Scene2AllSensor6.csv',
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'scene': ['Rennes', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene2/Scene2AllSensor3.csv',
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'scene': ['Rennes', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene2/Scene2AllSensor5.csv',
#    'participant': ['Rennes', 'Environment', 2, 5],
#    'scene': ['Rennes', 'Environment', 2, 2]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene3/Scene3AllSensor3.csv',
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'scene': ['Rennes', 'Environment', 2, 3]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene3/Scene3AllSensor6.csv',
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'scene': ['Rennes', 'Environment', 2, 3]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene3/Scene3AllSensor5.csv',
#    'participant': ['Rennes', 'Environment', 2, 5],
#    'scene': ['Rennes', 'Environment', 2, 3]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene3/Scene3AllSensor2.csv',
#    'participant': ['Rennes', 'Environment', 2, 2],
#    'scene': ['Rennes', 'Environment', 2, 3]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene4/Scene4AllSensor6.csv',
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'scene': ['Rennes', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene4/Scene4AllSensor2.csv',
#    'participant': ['Rennes', 'Environment', 2, 2],
#    'scene': ['Rennes', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene4/Scene4AllSensor5.csv',
#    'participant': ['Rennes', 'Environment', 2, 5],
#    'scene': ['Rennes', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene4/Scene4AllSensor3.csv',
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'scene': ['Rennes', 'Environment', 2, 4]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene5/Scene5AllSensor6.csv',
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'scene': ['Rennes', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene5/Scene5AllSensor2.csv',
#    'participant': ['Rennes', 'Environment', 2, 2],
#    'scene': ['Rennes', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene5/Scene5AllSensor5.csv',
#    'participant': ['Rennes', 'Environment', 2, 5],
#    'scene': ['Rennes', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene5/Scene5AllSensor3.csv',
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'scene': ['Rennes', 'Environment', 2, 5]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene6/Scene6AllSensor5.csv',
#    'participant': ['Rennes', 'Environment', 2, 5],
#    'scene': ['Rennes', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene6/Scene6AllSensor6.csv',
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'scene': ['Rennes', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene6/Scene6AllSensor3.csv',
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'scene': ['Rennes', 'Environment', 2, 6]}},
#  {'model': 'biosignalsindex.File',
#   'fields': {'id': None,
#    'path': 'Rennes/Environment/Session2/Sonifications/Scene6/Scene6AllSensor2.csv',
#    'participant': ['Rennes', 'Environment', 2, 2],
#    'scene': ['Rennes', 'Environment', 2, 6]}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Rennes/Environment/Session2/superepisode_scene_files.yaml', 'w') as f:
  yaml.safe_dump(files_fixtures, f)

# %% [markdown]
# # Generating biometric metadata

# %% [markdown]
# ## Generating peaks per scene

# %% [markdown]
# ### Eleusis

# %%
ids_path = os.path.join(session_og_path, 'IDs')

# %%
def findMetadata(name):
  rest = name.split("Scene")[1]
  meta = {}
  if(len(rest.split("HR")) != 1):
    meta['bio'] = "HR"
  elif(len(rest.split("SC")) != 1):
    meta['bio'] = 'SC'
  else:
    meta['bio'] = 'Temp'
  scene = rest.split(meta['bio'])[0]
  meta['scene'] = scene
  meta['sensor'] = rest.split("Sensor")[1].split("-")[0]
  return meta

# %%
ids = os.listdir(ids_path)
# dupes = fnmatch.filter(ids, "*(1)*")
# file_list = set(ids) - set(dupes)
fixtures = []
model_name = 'biosignalsindex.BioPeakMetadata'
for f in ids:
  meta = findMetadata(f)
  if int(meta['scene']) in scenes:
    fixture = {
        'model': model_name,
        'fields': {
            'scene': [city_name, thematic_name, session_id, meta['scene']],
            'participant': [city_name, thematic_name, session_id, meta['sensor']],
            'biometric': [meta['bio']]
        }
    }
    fixtures.append(fixture)

# %%
fixtures
# Out:
# [{'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Eleusis 2.0', 'Environment', 1, '76'],
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Eleusis 2.0', 'Environment', 1, '76'],
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Eleusis 2.0', 'Environment', 1, '76'],
#    'participant': ['Eleusis 2.0', 'Environment', 1, '6'],
#    'biometric': ['HR']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Eleusis 2.0', 'Environment', 1, '76'],
#    'participant': ['Eleusis 2.0', 'Environment', 1, '5'],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Eleusis 2.0', 'Environment', 1, '76'],
#    'participant': ['Eleusis 2.0', 'Environment', 1, '4'],
#    'biometric': ['HR']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Eleusis 2.0', 'Environment', 1, '76'],
#    'participant': ['Eleusis 2.0', 'Environment', 1, '3'],
#    'biometric': ['Temp']}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Eleusis 2.0/Environment/Session1/peak_metadata_76.yaml', 'w') as f:
  yaml.safe_dump(fixtures, f)

# %% [markdown]
# ### Ljubljana

# %%
ids_path = '/home/gina101/Session2/Scene_IDs_XLSX'

# %%
def findMetadata(name):
  rest = name.split("Scene")[1]
  meta = {}
  # if(len(rest.split("HR")) != 1):
  if "HR" in name:
    meta['bio'] = "HR"
  # elif(len(rest.split("SC")) != 1):
  elif "SC" in name:
    meta['bio'] = 'SC'
  else:
    meta['bio'] = 'Temp'
  # scene = rest.split(meta['bio'])[0]
  scene = rest.split('_')[0]
  meta['scene'] = int(scene)
  meta['sensor'] = int(rest.split("Sensor")[1].split("_")[0])
  return meta

# %%
ids = os.listdir(ids_path)
# dupes = fnmatch.filter(ids, "*(1)*")
# file_list = set(ids) - set(dupes)
file_list = ids
fixtures = []
model_name = 'biosignalsindex.BioPeakMetadata'
for f in file_list:
  meta = findMetadata(f)
  if int(meta['scene']) in scenes:
    fixture = {
        'model': model_name,
        'fields': {
            'scene': [city_name, thematic_name, session_id, meta['scene']],
            'participant': [city_name, thematic_name, session_id, meta['sensor']],
            'biometric': [meta['bio']]
        }
    }
    fixtures.append(fixture)

# %%
fixtures
# Out:
# [{'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 6],
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 2],
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 4],
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 2],
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'biometric': ['HR']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 1],
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 1],
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 3],
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 6],
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 1],
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 3],
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'biometric': ['HR']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 1],
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 5],
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 2],
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 2],
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 2],
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 1],
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 5],
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 3],
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 2],
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 4],
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'biometric': ['HR']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 4],
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 3],
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 6],
#    'participant': ['Ljubljana', 'Environment', 2, 3],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 1],
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 1],
#    'participant': ['Ljubljana', 'Environment', 2, 1],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 1],
#    'participant': ['Ljubljana', 'Environment', 2, 4],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Ljubljana', 'Environment', 2, 5],
#    'participant': ['Ljubljana', 'Environment', 2, 2],
#    'biometric': ['SC']}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Ljubljana/Environment/Session2/peak_metadata.yaml', 'w') as f:
  yaml.safe_dump(fixtures, f)

# %% [markdown]
# ### Rennes

# %%
def findMetadata(name):
  rest = name.split("Scene")[1]
  meta = {}
  # if(len(rest.split("HR")) != 1):
  if "HR" in name:
    meta['bio'] = "HR"
  # elif(len(rest.split("SC")) != 1):
  elif "SC" in name:
    meta['bio'] = 'SC'
  else:
    meta['bio'] = 'Temp'
  # scene = rest.split(meta['bio'])[0]
  scene = rest.split(meta['bio'])[0]
  meta['scene'] = int(scene)
  meta['sensor'] = int(rest.split("-")[0].split(meta['bio'])[1])
  return meta

# %%
ids = fnmatch.filter(os.listdir(session_og_path), "idScene*")
wanted_suffixes = ("HR3", "HR6", "Temp3", "Temp6", "SC3", "SC6")
file_list = [f for f in ids if any(suf in f for suf in wanted_suffixes)]
print(file_list)
fixtures = []
model_name = 'biosignalsindex.BioPeakMetadata'
for f in file_list:
  meta = findMetadata(f)
  print("Processing file for scene ", meta['scene'])
  if int(meta['scene']) in scenes:
    fixture = {
        'model': model_name,
        'fields': {
            'scene': [city_name, thematic_name, session_id, meta['scene']],
            'participant': [city_name, thematic_name, session_id, meta['sensor']],
            'biometric': [meta['bio']]
        }
    }
    fixtures.append(fixture)
# Out:
# ['idScene5Temp6-Task8.xlsx', 'idScene3SC3-Task7.xlsx', 'idScene1SC3-Task6.xlsx']
# Processing file for scene  5
# Processing file for scene  3
# Processing file for scene  1

# %%
fixtures
# Out:
# [{'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Rennes', 'Environment', 2, 5],
#    'participant': ['Rennes', 'Environment', 2, 6],
#    'biometric': ['Temp']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Rennes', 'Environment', 2, 3],
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'biometric': ['SC']}},
#  {'model': 'biosignalsindex.BioPeakMetadata',
#   'fields': {'scene': ['Rennes', 'Environment', 2, 1],
#    'participant': ['Rennes', 'Environment', 2, 3],
#    'biometric': ['SC']}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Rennes/Environment/Session2/peak_metadata_BONUS.yaml', 'w') as f:
  yaml.safe_dump(fixtures, f)

# %% [markdown]
# ## Generating min-max per task

# %% [markdown]
# ### Eleusis

# %%
import pandas as pd

# %%
visualizations_path = '/home/gina101/new_data/Eleusis 2.0/Environment/Session1/Visualizations'

# %%
section_folders = os.listdir(visualizations_path)

# %%
model_name = 'biosignalsindex.BiometricMetadataForTask'
meta_fixtures = []
biometrics = ['HR', 'SC', 'Temp']
for s in section_folders:
  s_path = os.path.join(visualizations_path, s)
  task_folders = os.listdir(s_path)
  for t in task_folders:
    if s =='Main' and t == 'Task3':
      # I'll come back to this later
      task_path = os.path.join(s_path, t)
      files = os.listdir(task_path)
      min = [500, 500, 500]
      max = [0, 0, 0]
      for f in files:
        f_path = os.path.join(task_path, f)
        df = pd.read_csv(f_path)
        for column in range(0, 3):
          series = df.iloc[:, column]
          if series.min() < min[column]:
            min[column] = series.min()
          if series.max() > max[column]:
            max[column] = series.max()
      for column, bio in enumerate(biometrics):
        fixture = {
            'model': model_name,
            'fields': {
                'biometric': [bio],
                'task': [city_name, thematic_name, session_id, s, t.split('Task')[1]],
                'min_value': str(min[column]),
                'max_value': str(max[column])
            }
        }
        meta_fixtures.append(fixture)
    else:
      continue

# %%
meta_fixtures
# Out:
# [{'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['HR'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '3'],
#    'min_value': '54.468085106382986',
#    'max_value': '178.6046511627907'}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['SC'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '3'],
#    'min_value': '0.6386946386946387',
#    'max_value': '12.505264770073133'}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['Temp'],
#    'task': ['Eleusis 2.0', 'Environment', 1, 'Main', '3'],
#    'min_value': '29.84959906475269',
#    'max_value': '32.88111471086741'}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Eleusis 2.0/Environment/Session1/bio_meta_main_3.yaml', 'w') as f:
  yaml.safe_dump(meta_fixtures, f)

# %% [markdown]
# ### Ljubljana

# %%
import pandas as pd

# %%
visualizations_path = '/home/gina101/new_data/Ljubljana/Environment/Session2/Visualizations'

# %%
model_name = 'biosignalsindex.BiometricMetadataForTask'
meta_fixtures = []
biometrics = ['HR', 'SC', 'Temp']
task_folders = os.listdir(visualizations_path)
for t in task_folders:
  task_path = os.path.join(visualizations_path, t)
  files = os.listdir(task_path)
  min = [500, 500, 500]
  max = [0, 0, 0]
  for f in files:
    f_path = os.path.join(task_path, f)
    df = pd.read_csv(f_path)
    for column in range(0, 3):
      series = df.iloc[:, column]
      if series.min() < min[column]:
        min[column] = series.min()
      if series.max() > max[column]:
        max[column] = series.max()
  for column, bio in enumerate(biometrics):
    fixture = {
        'model': model_name,
        'fields': {
            'biometric': [bio],
            'task': [city_name, thematic_name, session_id, int(t.split('Task')[1])],
            'min_value': float(min[column]),
            'max_value': float(max[column])
        }
    }
    meta_fixtures.append(fixture)

# %%
meta_fixtures
# Out:
# [{'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['HR'],
#    'task': ['Ljubljana', 'Environment', 2, 2],
#    'min_value': 45.71428571,
#    'max_value': 213.3333333}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['SC'],
#    'task': ['Ljubljana', 'Environment', 2, 2],
#    'min_value': 0.4572760574,
#    'max_value': 3.2827838828}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['Temp'],
#    'task': ['Ljubljana', 'Environment', 2, 2],
#    'min_value': 29.26943932,
#    'max_value': 32.70582663}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['HR'],
#    'task': ['Ljubljana', 'Environment', 2, 6],
#    'min_value': 47.40740741,
#    'max_value': 213.3333333}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['SC'],
#    'task': ['Ljubljana', 'Environment', 2, 6],
#    'min_value': 0.0137196137999999,
#    'max_value': 6.333039783}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['Temp'],
#    'task': ['Ljubljana', 'Environment', 2, 6],
#    'min_value': 30.86444529,
#    'max_value': 35.03504421}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['HR'],
#    'task': ['Ljubljana', 'Environment', 2, 1],
#    'min_value': 47.40740741,
#    'max_value': 207.5675676}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['SC'],
#    'task': ['Ljubljana', 'Environment', 2, 1],
#    'min_value': 0.0133644136,
#    'max_value': 2.944322344}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['Temp'],
#    'task': ['Ljubljana', 'Environment', 2, 1],
#    'min_value': 28.87812259,
#    'max_value': 32.55778533}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['HR'],
#    'task': ['Ljubljana', 'Environment', 2, 5],
#    'min_value': 45.71428571,
#    'max_value': 213.3333333}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['SC'],
#    'task': ['Ljubljana', 'Environment', 2, 5],
#    'min_value': 0.0059052058,
#    'max_value': 5.848042782}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['Temp'],
#    'task': ['Ljubljana', 'Environment', 2, 5],
#    'min_value': 30.44612763,
#    'max_value': 34.25040647}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['HR'],
#    'task': ['Ljubljana', 'Environment', 2, 4],
#    'min_value': 49.5483871,
#    'max_value': 213.3333333}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['SC'],
#    'task': ['Ljubljana', 'Environment', 2, 4],
#    'min_value': 0.0126540126,
#    'max_value': 3.8017582416}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['Temp'],
#    'task': ['Ljubljana', 'Environment', 2, 4],
#    'min_value': 30.2155417,
#    'max_value': 32.90321544}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Ljubljana/Environment/Session2/bio_metadata.yaml', 'w') as f:
  yaml.safe_dump(meta_fixtures, f)

# %% [markdown]
# ### Rennes

# %%
import pandas as pd

# %%
visualizations_path = '/home/gina101/new_data/Rennes/Environment/Session2/Visualizations'

# %%
model_name = 'biosignalsindex.BiometricMetadataForTask'
meta_fixtures = []
biometrics = ['HR', 'SC', 'Temp']
task_folders = os.listdir(visualizations_path)
for t in task_folders:
  task_path = os.path.join(visualizations_path, t)
  files = os.listdir(task_path)
  min = [500, 500, 500]
  max = [0, 0, 0]
  for f in files:
    f_path = os.path.join(task_path, f)
    df = pd.read_csv(f_path)
    for column in range(0, 3):
      series = df.iloc[:, column]
      if series.min() < min[column]:
        min[column] = series.min()
      if series.max() > max[column]:
        max[column] = series.max()
  for column, bio in enumerate(biometrics):
    fixture = {
        'model': model_name,
        'fields': {
            'biometric': [bio],
            'task': [city_name, thematic_name, session_id, int(t.split('Task')[1])],
            'min_value': float(min[column]),
            'max_value': float(max[column])
        }
    }
    meta_fixtures.append(fixture)

# %%
meta_fixtures
# Out:
# [{'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['HR'],
#    'task': ['Rennes', 'Environment', 2, 6],
#    'min_value': 20.72425491935906,
#    'max_value': 188.8106312292359}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['SC'],
#    'task': ['Rennes', 'Environment', 2, 6],
#    'min_value': 1.927472527472527,
#    'max_value': 21.12149873343903}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['Temp'],
#    'task': ['Rennes', 'Environment', 2, 6],
#    'min_value': 30.32365508675575,
#    'max_value': 32.32904663681984}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['HR'],
#    'task': ['Rennes', 'Environment', 2, 7],
#    'min_value': 39.31234305582385,
#    'max_value': 186.9842979541879}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['SC'],
#    'task': ['Rennes', 'Environment', 2, 7],
#    'min_value': 0.0246420246420246,
#    'max_value': 24.4018005212035}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['Temp'],
#    'task': ['Rennes', 'Environment', 2, 7],
#    'min_value': 30.40801287587383,
#    'max_value': 32.46883474218193}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['HR'],
#    'task': ['Rennes', 'Environment', 2, 8],
#    'min_value': 41.22081949058695,
#    'max_value': 188.2387444151679}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['SC'],
#    'task': ['Rennes', 'Environment', 2, 8],
#    'min_value': 0.0122100122100122,
#    'max_value': 23.08967980609771}},
#  {'model': 'biosignalsindex.BiometricMetadataForTask',
#   'fields': {'biometric': ['Temp'],
#    'task': ['Rennes', 'Environment', 2, 8],
#    'min_value': 30.10531767020002,
#    'max_value': 32.51635503845755}}]

# %%
with open('/home/gina101/tt8/backend/tt8_backend/biosignalsindex/fixtures/Rennes/Environment/Session2/bio_metadata.yaml', 'w') as f:
  yaml.safe_dump(meta_fixtures, f)
